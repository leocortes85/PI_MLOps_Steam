# %%
import pandas as pd
import json
import ast

# %load_ext autoreload
# %autoreload 2
import utils as ut

import warnings
warnings.filterwarnings("ignore")

# %%
# Ruta al dataset australian_user_reviews
path = 'data/json/australian_users_items.json'

rows = []

with open (path, encoding='utf-8') as f:
    for line in f.readlines():
        rows.append(ast.literal_eval(line))

df_uitems = pd.DataFrame(rows)

df_uitems
# Out:
#                        user_id  items_count           steam_id  \
# 0            76561197970982479          277  76561197970982479
# 1                      js41637          888  76561198035864385
# 2                    evcentric          137  76561198007712555
# 3                   Riot-Punch          328  76561197963445855
# 4                        doctr          541  76561198002099482
# ...                        ...          ...                ...
# 88305        76561198323066619           22  76561198323066619
# 88306        76561198326700687          177  76561198326700687
# 88307  XxLaughingJackClown77xX            0  76561198328759259
# 88308        76561198329548331            7  76561198329548331
# 88309        edward_tremethick            0  76561198331598578
#
#                                                 user_url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 1                   http://steamcommunity.com/id/js41637
# ...

# %% [markdown]
# We are going to expand the data that is nested in the items column

# %%
ut.data_summ(df_uitems)
# Out:
# Total rows:  88310
#
# Total full null rows:  0
#         Column         Data_type  No_miss_Qty  %Missing  Missing_Qty
# 0      user_id   [<class 'str'>]        88310       0.0            0
# 1  items_count   [<class 'int'>]        88310       0.0            0
# 2     steam_id   [<class 'str'>]        88310       0.0            0
# 3     user_url   [<class 'str'>]        88310       0.0            0
# 4        items  [<class 'list'>]        88310       0.0            0

# %%
df_items = pd.json_normalize(rows, record_path=['items'], meta=['user_id','items_count','steam_id','user_url'] )
df_items
# Out:
#         item_id                      item_name  playtime_forever  \
# 0            10                 Counter-Strike                 6
# 1            20          Team Fortress Classic                 0
# 2            30                  Day of Defeat                 7
# 3            40             Deathmatch Classic                 0
# 4            50      Half-Life: Opposing Force                 0
# ...         ...                            ...               ...
# 5153204  346330                   BrainBread 2                 0
# 5153205  373330                    All Is Dust                 0
# 5153206  388490  One Way To Die: Steam Edition                 3
# 5153207  521570          You Have 10 Seconds 2                 4
# 5153208  519140                     Minds Eyes                 3
#
#          playtime_2weeks            user_id items_count           steam_id  \
# 0                      0  76561197970982479         277  76561197970982479
# ...

# %%
ut.data_summ(df_items)
# Out:
# Total rows:  5153209
#
# Total full null rows:  0
#              Column        Data_type  No_miss_Qty  %Missing  Missing_Qty
# 0           item_id  [<class 'str'>]      5153209       0.0            0
# 1         item_name  [<class 'str'>]      5153209       0.0            0
# 2  playtime_forever  [<class 'int'>]      5153209       0.0            0
# 3   playtime_2weeks  [<class 'int'>]      5153209       0.0            0
# 4           user_id  [<class 'str'>]      5153209       0.0            0
# 5       items_count  [<class 'int'>]      5153209       0.0            0
# 6          steam_id  [<class 'str'>]      5153209       0.0            0
# 7          user_url  [<class 'str'>]      5153209       0.0            0

# %%
duplicated = df_items.loc[df_items.duplicated()]
duplicated
# Out:
#         item_id                         item_name  playtime_forever  \
# 164294       20             Team Fortress Classic                 5
# 164295       50         Half-Life: Opposing Force                 0
# 164296       70                         Half-Life                 0
# 164297      130             Half-Life: Blue Shift                 0
# 164298      220                       Half-Life 2               198
# ...         ...                               ...               ...
# 4898223  213670  South Park™: The Stick of Truth™               725
# 4898224  221910               The Stanley Parable                53
# 4898225  261030      The Walking Dead: Season Two               253
# 4898226  273110     Counter-Strike Nexon: Zombies                 0
# 4898227     730  Counter-Strike: Global Offensive                 0
#
#          playtime_2weeks            user_id items_count           steam_id  \
# ...

# %%
df_items.drop_duplicates(inplace=True)

# %%
df_items = df_items.drop('playtime_2weeks', axis=1)
df_items
# Out:
#         item_id                      item_name  playtime_forever  \
# 0            10                 Counter-Strike                 6
# 1            20          Team Fortress Classic                 0
# 2            30                  Day of Defeat                 7
# 3            40             Deathmatch Classic                 0
# 4            50      Half-Life: Opposing Force                 0
# ...         ...                            ...               ...
# 5153204  346330                   BrainBread 2                 0
# 5153205  373330                    All Is Dust                 0
# 5153206  388490  One Way To Die: Steam Edition                 3
# 5153207  521570          You Have 10 Seconds 2                 4
# 5153208  519140                     Minds Eyes                 3
#
#                    user_id items_count           steam_id  \
# 0        76561197970982479         277  76561197970982479
# 1        76561197970982479         277  76561197970982479
# ...

# %%
dataframe = [df_items]
name = ['uitems_clean']
ut.save_to_csv(dataframe, name)
# Out:
# DataFrame 'uitems_clean' saved as 'data/csv/uitems_clean.csv'
